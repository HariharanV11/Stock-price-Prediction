# %% [markdown]
# <a href="https://colab.research.google.com/github/HariharanV11/Stock-price-Prediction/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from copy import deepcopy
import yfinance as yf

# Fetch historical data for the last 1 year for 'AAPL'
ticker = 'AAPL'
df = yf.download(ticker, period="1y")  # '1y' stands for 1 year

# Display the data
print(df)

# Reset index and select required columns
df = df.reset_index()
df = df[['Date', 'Close']]
df['Date'] = pd.to_datetime(df['Date'])  # Convert Date to datetime format

# Ensure the 'Date' column is timezone-naive (removes timezone information if any)
df['Date'] = df['Date'].dt.tz_localize(None)  # This removes any timezone information if present

# Set 'Date' as index again after making sure it's timezone-naive
df.set_index('Date', inplace=True)

# Function to convert string to datetime (for compatibility)
def str_to_datetime(s):
    year, month, day = map(int, s.split('-'))
    return datetime.datetime(year=year, month=month, day=day)

# Windowing function
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = str_to_datetime(first_date_str)
    last_date = str_to_datetime(last_date_str)

    target_date = first_date
    dates = []
    X, Y = [], []

    last_time = False
    while True:
        # Slice data up to the target_date
        df_subset = dataframe.loc[:target_date].tail(n+1)
        if len(df_subset) != n+1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return None  # Return None if window size is too large

        values = df_subset['Close'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        # Move to next date
        next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
        if next_week.empty:
            break
        next_datetime_str = str(next_week.head(2).tail(1).index[0])
        next_date_str = next_datetime_str.split('T')[0]
        next_date = pd.to_datetime(next_date_str)

        if last_time:
            break

        target_date = next_date
        if target_date >= last_date:
            last_time = True

    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates
    X = np.array(X)
    for i in range(n):
        ret_df[f'Target-{n-i}'] = X[:, i]
    ret_df['Target'] = Y

    return ret_df

# Generate windowed data
windowed_df = df_to_windowed_df(df, '2023-12-01', '2024-11-08', n=3)

# Check if the windowed_df is None (i.e., the function couldn't generate valid windows)
if windowed_df is None:
    print("Unable to generate windowed data due to insufficient data.")
else:
    # Separate features and labels
    def windowed_df_to_date_X_y(windowed_dataframe):
        df_as_np = windowed_dataframe.to_numpy()
        dates = df_as_np[:, 0]
        middle_matrix = df_as_np[:, 1:-1]
        X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
        Y = df_as_np[:, -1]
        return dates, X.astype(np.float32), Y.astype(np.float32)

    dates, X, y = windowed_df_to_date_X_y(windowed_df)

    # Split data into train, validation, and test sets
    q_80 = int(len(dates) * 0.8)
    q_90 = int(len(dates) * 0.9)

    dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
    dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
    dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

    # Plotting train, validation, and test sets
    plt.figure(figsize=(12, 6))
    plt.plot(dates_train, y_train)
    plt.plot(dates_val, y_val)
    plt.plot(dates_test, y_test)
    plt.legend(['Train', 'Validation', 'Test'])
    plt.show()

    # Model definition and training
    model = Sequential([
        layers.Input((3, 1)),
        layers.LSTM(64),
        layers.Dense(32, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)

    # Predictions
    train_predictions = model.predict(X_train).flatten()
    val_predictions = model.predict(X_val).flatten()
    test_predictions = model.predict(X_test).flatten()

    # Plot predictions and actual values
    plt.figure(figsize=(12, 6))
    plt.plot(dates_train, train_predictions)
    plt.plot(dates_train, y_train)
    plt.plot(dates_val, val_predictions)
    plt.plot(dates_val, y_val)
    plt.plot(dates_test, test_predictions)
    plt.plot(dates_test, y_test)
    plt.legend(['Train Predictions', 'Train Actual', 'Val Predictions', 'Val Actual', 'Test Predictions', 'Test Actual'])
    plt.show()

    # Recursive predictions
    recursive_predictions = []
    recursive_dates = np.concatenate([dates_val, dates_test])
    last_window = deepcopy(X_train[-1])

    for _ in recursive_dates:
        next_prediction = model.predict(np.array([last_window])).flatten()
        recursive_predictions.append(next_prediction)
        last_window = np.roll(last_window, -1)
        last_window[-1] = next_prediction  # Slide window to include the latest prediction

    # Plot recursive predictions
    plt.figure(figsize=(12, 6))
    plt.plot(dates_train, train_predictions)
    plt.plot(dates_train, y_train)
    plt.plot(dates_val, val_predictions)
    plt.plot(dates_val, y_val)
    plt.plot(dates_test, test_predictions)
    plt.plot(dates_test, y_test)
    plt.plot(recursive_dates, recursive_predictions)
    plt.legend(['Train Predictions', 'Train Actual', 'Val Predictions', 'Val Actual', 'Test Predictions', 'Test Actual', 'Recursive Predictions'])
    plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2023-11-20 00:00:00+00:00  190.516647  191.449997  191.910004  189.880005
# 2023-11-21 00:00:00+00:00  189.710602  190.639999  191.520004  189.740005
# 2023-11-22 00:00:00+00:00  190.377350  191.309998  192.929993  190.830002
# 2023-11-24 00:00:00+00:00  189.043869  189.970001  190.899994  189.250000
# 2023-11-27 00:00:00+00:00  188.864731  189.789993  190.669998  188.899994
# ...                               ...         ...         ...         ...
# 2024-11-12 00:00:00+00:00  224.229996  224.229996  225.589996  223.360001
# 2024-11-13 00:00:00+00:00  225.119995  225.119995  226.649994  222.759995
# 2024-11-14 00:00:00+00:00  228.220001  228.220001  228.869995  225.000000
# 2024-11-15 00:00:00+00:00  225.000000  225.000000  226.919998  224.270004
# 2024-11-18 00:00:00+00:00  228.854996  228.854996  229.740005  225.179993
#
# Price                            Open    Volume
# Ticker                           AAPL      AAPL
# Date
# 2023-11-20 00:00:00+00:00  189.889999  46505100
# 2023-11-21 00:00:00+00:00  191.410004  38134500
# 2023-11-22 00:00:00+00:00  191.490005  39617700
# 2023-11-24 00:00:00+00:00  190.869995  24048300
# 2023-11-27 00:00:00+00:00  189.919998  40552600
# ...                               ...       ...
# 2024-11-12 00:00:00+00:00  224.550003  40398300
# 2024-11-13 00:00:00+00:00  224.009995  48566200
# 2024-11-14 00:00:00+00:00  225.020004  44923900
# 2024-11-15 00:00:00+00:00  226.399994  47832200
# 2024-11-18 00:00:00+00:00  225.199997  22893753
#
# [251 rows x 6 columns]
# <ipython-input-2-4ea5c2391d50>:96: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return dates, X.astype(np.float32), Y.astype(np.float32)
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 38441.8945 - mean_absolute_error: 195.1001 - val_loss: 49972.1250 - val_mean_absolute_error: 223.5095
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 38168.8438 - mean_absolute_error: 194.3026 - val_loss: 49804.8438 - val_mean_absolute_error: 223.1350
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 37601.4883 - mean_absolute_error: 192.9241 - val_loss: 49666.0195 - val_mean_absolute_error: 222.8237
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 37764.3555 - mean_absolute_error: 193.3280 - val_loss: 49484.2344 - val_mean_absolute_error: 222.4154
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 38126.5273 - mean_absolute_error: 194.2491 - val_loss: 49200.3867 - val_mean_absolute_error: 221.7763
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 36958.9570 - mean_absolute_error: 191.2228 - val_loss: 48799.5742 - val_mean_absolute_error: 220.8708
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 36564.5742 - mean_absolute_error: 190.2728 - val_loss: 48295.2305 - val_mean_absolute_error: 219.7262
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 36291.5938 - mean_absolute_error: 189.5204 - val_loss: 47610.8555 - val_mean_absolute_error: 218.1632
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 36226.3828 - mean_absolute_error: 189.3008 - val_loss: 46776.9062 - val_mean_absolute_error: 216.2435
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 34572.6602 - mean_absolute_error: 184.9532 - val_loss: 45796.5195 - val_mean_absolute_error: 213.9646
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 33788.8828 - mean_absolute_error: 182.6980 - val_loss: 44421.4180 - val_mean_absolute_error: 210.7268
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33026.2773 - mean_absolute_error: 180.6237 - val_loss: 42977.3477 - val_mean_absolute_error: 207.2720
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 31725.2949 - mean_absolute_error: 177.0177 - val_loss: 41195.3828 - val_mean_absolute_error: 202.9278
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 29949.5508 - mean_absolute_error: 171.9680 - val_loss: 39093.9258 - val_mean_absolute_error: 197.6822
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 28039.2305 - mean_absolute_error: 166.3146 - val_loss: 36815.7812 - val_mean_absolute_error: 191.8336
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 26167.2773 - mean_absolute_error: 160.5641 - val_loss: 34367.0977 - val_mean_absolute_error: 185.3414
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 24227.6289 - mean_absolute_error: 154.3192 - val_loss: 31652.0938 - val_mean_absolute_error: 177.8664
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 21708.5039 - mean_absolute_error: 146.0096 - val_loss: 28943.7188 - val_mean_absolute_error: 170.0826
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19439.3496 - mean_absolute_error: 138.0523 - val_loss: 26141.3438 - val_mean_absolute_error: 161.6345
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17358.0273 - mean_absolute_error: 130.3288 - val_loss: 23270.8281 - val_mean_absolute_error: 152.4965
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 15189.7783 - mean_absolute_error: 121.5903 - val_loss: 20305.3613 - val_mean_absolute_error: 142.4417
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 12237.1543 - mean_absolute_error: 108.9020 - val_loss: 17230.4668 - val_mean_absolute_error: 131.2051
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10094.4707 - mean_absolute_error: 98.5841 - val_loss: 14333.4912 - val_mean_absolute_error: 119.6573
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8002.4189 - mean_absolute_error: 87.2658 - val_loss: 11687.3174 - val_mean_absolute_error: 108.0352
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6109.2041 - mean_absolute_error: 75.2824 - val_loss: 9000.8633 - val_mean_absolute_error: 94.7901
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4325.8936 - mean_absolute_error: 62.3114 - val_loss: 6560.0718 - val_mean_absolute_error: 80.8963
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2582.1680 - mean_absolute_error: 47.0580 - val_loss: 4593.4482 - val_mean_absolute_error: 67.6592
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1661.8534 - mean_absolute_error: 35.3371 - val_loss: 3098.3269 - val_mean_absolute_error: 55.5203
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 919.4644 - mean_absolute_error: 23.9190 - val_loss: 2035.5439 - val_mean_absolute_error: 44.9417
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 539.9040 - mean_absolute_error: 17.5780 - val_loss: 1312.0156 - val_mean_absolute_error: 36.0042
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 396.0182 - mean_absolute_error: 15.9798 - val_loss: 875.3821 - val_mean_absolute_error: 29.3214
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 398.5988 - mean_absolute_error: 17.1566 - val_loss: 698.2593 - val_mean_absolute_error: 26.1273
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 368.7282 - mean_absolute_error: 16.9390 - val_loss: 672.6558 - val_mean_absolute_error: 25.6326
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 416.2399 - mean_absolute_error: 18.0411 - val_loss: 695.5182 - val_mean_absolute_error: 26.0749
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 389.1255 - mean_absolute_error: 17.2073 - val_loss: 777.9139 - val_mean_absolute_error: 27.6113
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 354.1879 - mean_absolute_error: 15.5710 - val_loss: 862.6568 - val_mean_absolute_error: 29.1115
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 337.4572 - mean_absolute_error: 15.0436 - val_loss: 897.2380 - val_mean_absolute_error: 29.7043
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 386.7446 - mean_absolute_error: 16.3080 - val_loss: 895.9705 - val_mean_absolute_error: 29.6847
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 336.9251 - mean_absolute_error: 14.8583 - val_loss: 773.9070 - val_mean_absolute_error: 27.5445
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 341.0526 - mean_absolute_error: 15.3361 - val_loss: 826.8383 - val_mean_absolute_error: 28.4963
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 339.5276 - mean_absolute_error: 15.3697 - val_loss: 786.8918 - val_mean_absolute_error: 27.7845
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 359.6180 - mean_absolute_error: 16.2504 - val_loss: 796.1099 - val_mean_absolute_error: 27.9529
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 314.6502 - mean_absolute_error: 14.3442 - val_loss: 806.3594 - val_mean_absolute_error: 28.1364
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 296.2516 - mean_absolute_error: 14.1970 - val_loss: 722.3613 - val_mean_absolute_error: 26.5981
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 319.0247 - mean_absolute_error: 14.6821 - val_loss: 756.1997 - val_mean_absolute_error: 27.2351
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 306.4801 - mean_absolute_error: 14.3554 - val_loss: 715.7507 - val_mean_absolute_error: 26.4760
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 309.9521 - mean_absolute_error: 14.7336 - val_loss: 795.6891 - val_mean_absolute_error: 27.9566
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 343.3289 - mean_absolute_error: 15.2867 - val_loss: 714.7458 - val_mean_absolute_error: 26.4601
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 326.5398 - mean_absolute_error: 15.2432 - val_loss: 747.1414 - val_mean_absolute_error: 27.0743
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 305.4684 - mean_absolute_error: 14.3324 - val_loss: 700.1345 - val_mean_absolute_error: 26.1858
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 300.0132 - mean_absolute_error: 14.2073 - val_loss: 727.8419 - val_mean_absolute_error: 26.7141
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 308.6810 - mean_absolute_error: 14.4686 - val_loss: 687.6923 - val_mean_absolute_error: 25.9539
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 289.9117 - mean_absolute_error: 13.8975 - val_loss: 804.7858 - val_mean_absolute_error: 28.1301
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 247.5344 - mean_absolute_error: 12.3709 - val_loss: 679.4268 - val_mean_absolute_error: 25.8020
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 244.9348 - mean_absolute_error: 12.4126 - val_loss: 603.6107 - val_mean_absolute_error: 24.2879
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 227.8365 - mean_absolute_error: 12.2417 - val_loss: 656.8569 - val_mean_absolute_error: 25.3753
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 223.9703 - mean_absolute_error: 11.6820 - val_loss: 542.4656 - val_mean_absolute_error: 23.0002
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 201.9522 - mean_absolute_error: 11.3436 - val_loss: 512.5461 - val_mean_absolute_error: 22.3463
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 217.2284 - mean_absolute_error: 11.9592 - val_loss: 479.9827 - val_mean_absolute_error: 21.6102
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 203.0404 - mean_absolute_error: 11.6630 - val_loss: 531.9241 - val_mean_absolute_error: 22.7950
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 180.9751 - mean_absolute_error: 10.7977 - val_loss: 470.7183 - val_mean_absolute_error: 21.4086
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 151.0580 - mean_absolute_error: 9.5582 - val_loss: 367.5855 - val_mean_absolute_error: 18.8277
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 164.4214 - mean_absolute_error: 10.6960 - val_loss: 407.1524 - val_mean_absolute_error: 19.8734
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 156.2232 - mean_absolute_error: 10.3554 - val_loss: 460.3972 - val_mean_absolute_error: 21.1944
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 139.1024 - mean_absolute_error: 9.1785 - val_loss: 267.5361 - val_mean_absolute_error: 15.9581
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 136.6053 - mean_absolute_error: 10.0839 - val_loss: 392.8710 - val_mean_absolute_error: 19.5417
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 100.2600 - mean_absolute_error: 8.0075 - val_loss: 271.2332 - val_mean_absolute_error: 16.1052
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 105.7884 - mean_absolute_error: 8.0359 - val_loss: 260.2555 - val_mean_absolute_error: 15.7865
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 81.6263 - mean_absolute_error: 6.8523 - val_loss: 179.8278 - val_mean_absolute_error: 12.9709
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 70.8215 - mean_absolute_error: 6.4828 - val_loss: 167.1923 - val_mean_absolute_error: 12.4890
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 59.3644 - mean_absolute_error: 5.8942 - val_loss: 129.9395 - val_mean_absolute_error: 10.8932
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 53.9014 - mean_absolute_error: 5.7862 - val_loss: 94.3447 - val_mean_absolute_error: 9.1034
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 46.6612 - mean_absolute_error: 5.6398 - val_loss: 101.5770 - val_mean_absolute_error: 9.5274
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 39.7677 - mean_absolute_error: 4.9435 - val_loss: 81.5506 - val_mean_absolute_error: 8.4140
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 33.2033 - mean_absolute_error: 4.6473 - val_loss: 85.7131 - val_mean_absolute_error: 8.6783
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.9801 - mean_absolute_error: 4.0371 - val_loss: 68.7348 - val_mean_absolute_error: 7.6334
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.5025 - mean_absolute_error: 3.9371 - val_loss: 45.1287 - val_mean_absolute_error: 5.9971
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 24.4587 - mean_absolute_error: 3.9956 - val_loss: 30.0735 - val_mean_absolute_error: 4.6842
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 33.0142 - mean_absolute_error: 4.8687 - val_loss: 38.8021 - val_mean_absolute_error: 5.5063
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 24.1858 - mean_absolute_error: 4.1792 - val_loss: 52.8015 - val_mean_absolute_error: 6.6001
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 21.6151 - mean_absolute_error: 3.5706 - val_loss: 42.5219 - val_mean_absolute_error: 5.8304
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.6897 - mean_absolute_error: 3.2410 - val_loss: 31.0625 - val_mean_absolute_error: 4.8069
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 18.3064 - mean_absolute_error: 3.2401 - val_loss: 19.8040 - val_mean_absolute_error: 3.6241
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 15.8380 - mean_absolute_error: 3.0639 - val_loss: 19.1223 - val_mean_absolute_error: 3.5557
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.3529 - mean_absolute_error: 3.0762 - val_loss: 17.8012 - val_mean_absolute_error: 3.4068
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.5548 - mean_absolute_error: 2.9041 - val_loss: 26.3004 - val_mean_absolute_error: 4.3212
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 12.9021 - mean_absolute_error: 2.7733 - val_loss: 17.9603 - val_mean_absolute_error: 3.4312
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.4553 - mean_absolute_error: 2.7056 - val_loss: 13.2736 - val_mean_absolute_error: 2.8569
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.9321 - mean_absolute_error: 2.8977 - val_loss: 13.3632 - val_mean_absolute_error: 2.8610
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.6002 - mean_absolute_error: 2.7381 - val_loss: 13.0536 - val_mean_absolute_error: 2.8164
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.8206 - mean_absolute_error: 2.7113 - val_loss: 11.6366 - val_mean_absolute_error: 2.6318
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.5111 - mean_absolute_error: 2.7031 - val_loss: 15.9747 - val_mean_absolute_error: 3.1858
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4933 - mean_absolute_error: 2.3574 - val_loss: 15.7403 - val_mean_absolute_error: 3.1540
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.4627 - mean_absolute_error: 2.4817 - val_loss: 12.9963 - val_mean_absolute_error: 2.7887
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.6759 - mean_absolute_error: 2.4314 - val_loss: 13.2689 - val_mean_absolute_error: 2.8177
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6904 - mean_absolute_error: 2.3317 - val_loss: 11.5033 - val_mean_absolute_error: 2.6003
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.2082 - mean_absolute_error: 2.5612 - val_loss: 9.7738 - val_mean_absolute_error: 2.3237
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.7000 - mean_absolute_error: 2.6615 - val_loss: 9.7428 - val_mean_absolute_error: 2.3151
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.8026 - mean_absolute_error: 2.7844 - val_loss: 10.8475 - val_mean_absolute_error: 2.5103
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.9685 - mean_absolute_error: 2.6004 - val_loss: 10.6939 - val_mean_absolute_error: 2.4847
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Calculate MSE and MAE for train, validation, and test sets
train_mse = mean_squared_error(y_train, train_predictions)
val_mse = mean_squared_error(y_val, val_predictions)
test_mse = mean_squared_error(y_test, test_predictions)

train_mae = mean_absolute_error(y_train, train_predictions)
val_mae = mean_absolute_error(y_val, val_predictions)
test_mae = mean_absolute_error(y_test, test_predictions)

# Print out the MSE and MAE for each set
print(f"Train MSE: {train_mse}")
print(f"Validation MSE: {val_mse}")
print(f"Test MSE: {test_mse}")
print(f"Train MAE: {train_mae}")
print(f"Validation MAE: {val_mae}")
print(f"Test MAE: {test_mae}")
# Out:
# Train MSE: 10.457012176513672
# Validation MSE: 10.693862915039062
# Test MSE: 23.100797653198242
# Train MAE: 2.428901433944702
# Validation MAE: 2.484661102294922
# Test MAE: 4.146620273590088
