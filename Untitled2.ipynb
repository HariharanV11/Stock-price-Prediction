# %% [markdown]
# <a href="https://colab.research.google.com/github/HariharanV11/Stock-price-Prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from pandas.tseries.offsets import DateOffset

# Step 1: Fetch the data
ticker = 'AAPL'
df = yf.download(ticker, period="1y")  # Download 1 year of data
df = df[['Close']]  # Keep only the 'Close' column

# Step 2: Preprocessing
df['Date'] = pd.to_datetime(df.index)  # Ensure 'Date' is datetime
df.set_index('Date', inplace=True)  # Set 'Date' as index
df.index = pd.to_datetime(df.index).tz_localize(None)  # Remove timezone info

# Step 3: Stationarity Check (ADF Test)
def adfuller_test(series):
    result = adfuller(series)
    labels = ['ADF Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f"{label}: {value}")
    if result[1] <= 0.05:
        print("Series is stationary.")
    else:
        print("Series is non-stationary.")

# Original Series
print("\nADF Test on Original Series:")
adfuller_test(df['Close'])

# Step 4: Differencing for Stationarity
df['First Difference'] = df['Close'] - df['Close'].shift(1)
df['Seasonal Difference'] = df['Close'] - df['Close'].shift(12)

# Check stationarity after differencing
print("\nADF Test on First Difference:")
adfuller_test(df['First Difference'].dropna())
print("\nADF Test on Seasonal Difference:")
adfuller_test(df['Seasonal Difference'].dropna())

# Step 5: Plot ACF and PACF for Seasonal Differenced Series
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plot_acf(df['Seasonal Difference'].dropna(), lags=40, ax=axes[0])
axes[0].set_title("ACF Plot")
plot_pacf(df['Seasonal Difference'].dropna(), lags=40, ax=axes[1])
axes[1].set_title("PACF Plot")
plt.show()

# Step 6: SARIMAX Model
model = sm.tsa.statespace.SARIMAX(df['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
results = model.fit()

# Model Summary
print(results.summary())

# Step 7: Forecasting within existing data range
df['forecast'] = results.predict(start=len(df) - 30, end=len(df) - 1, dynamic=True)
df[['Close', 'forecast']].plot(figsize=(12, 8), title="Historical Forecast")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ADF Test on Original Series:
# ADF Test Statistic: -0.8155898029288497
# p-value: 0.8144997341990363
# #Lags Used: 0
# Number of Observations Used: 251
# Series is non-stationary.
#
# ADF Test on First Difference:
# ADF Test Statistic: -14.937953227480625
# p-value: 1.3358137634787129e-27
# #Lags Used: 0
# Number of Observations Used: 250
# Series is stationary.
#
# ADF Test on Seasonal Difference:
# ADF Test Statistic: -2.6012540709076446
# p-value: 0.09273835339729486
# #Lags Used: 13
# Number of Observations Used: 226
# Series is non-stationary.
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               AAPL   No. Observations:                  252
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -609.412
# Date:                            Sat, 16 Nov 2024   AIC                           1228.823
# Time:                                    13:53:10   BIC                           1246.205
# Sample:                                         0   HQIC                          1235.828
#                                             - 252
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0948      1.175     -0.081      0.936      -2.397       2.207
# ma.L1          0.1591      1.158      0.137      0.891      -2.110       2.428
# ar.S.L12       0.0013      0.059      0.022      0.982      -0.115       0.117
# ma.S.L12      -0.9991      5.916     -0.169      0.866     -12.595      10.596
# sigma2         8.2492     48.620      0.170      0.865     -87.045     103.543
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               119.13
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.13   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
actual = df['Close'][-30:]
predicted = df['forecast'][-30:]

# %%
accuracy=(predicted/actual)*100

# %%
average_accuracy = np.mean(accuracy)
print("Average accuracy:", average_accuracy)
# Out:
# Average accuracy: nan

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm
from pandas.tseries.offsets import DateOffset
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Step 1: Fetch the data
ticker = 'AAPL'
df = yf.download(ticker, period="1y")  # Download 1 year of data
df = df[['Close']]  # Keep only the 'Close' column

# Step 2: Preprocessing
df['Date'] = pd.to_datetime(df.index)  # Ensure 'Date' is datetime
df.set_index('Date', inplace=True)  # Set 'Date' as index
df.index = pd.to_datetime(df.index).tz_localize(None)  # Remove timezone info

# Step 3: Stationarity Check (ADF Test)
def adfuller_test(series):
    result = adfuller(series)
    labels = ['ADF Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used']
    for value, label in zip(result, labels):
        print(f"{label}: {value}")
    if result[1] <= 0.05:
        print("Series is stationary.")
    else:
        print("Series is non-stationary.")

# Original Series
print("\nADF Test on Original Series:")
adfuller_test(df['Close'])

# Step 4: Differencing for Stationarity
df['First Difference'] = df['Close'] - df['Close'].shift(1)
df['Seasonal Difference'] = df['Close'] - df['Close'].shift(12)

# Check stationarity after differencing
print("\nADF Test on First Difference:")
adfuller_test(df['First Difference'].dropna())
print("\nADF Test on Seasonal Difference:")
adfuller_test(df['Seasonal Difference'].dropna())

# Step 5: Plot ACF and PACF for Seasonal Differenced Series
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
plot_acf(df['Seasonal Difference'].dropna(), lags=40, ax=axes[0])
axes[0].set_title("ACF Plot")
plot_pacf(df['Seasonal Difference'].dropna(), lags=40, ax=axes[1])
axes[1].set_title("PACF Plot")
plt.show()

# Step 6: SARIMAX Model
model = sm.tsa.statespace.SARIMAX(df['Close'], order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
results = model.fit()

# Model Summary
print(results.summary())

# Step 7: Forecasting within existing data range
df['forecast'] = results.predict(start=len(df) - 30, end=len(df) - 1, dynamic=True)

# Step 8: Calculate Accuracy
# Actual values for the last 30 days
actual = df['Close'][-30:]

# Predicted forecasted values for the last 30 days
predicted = df['forecast'][-30:]

# Calculate accuracy metrics
mae = mean_absolute_error(actual, predicted)  # Mean Absolute Error
mse = mean_squared_error(actual, predicted)  # Mean Squared Error
rmse = np.sqrt(mse)  # Root Mean Squared Error

# Print accuracy metrics
print("\nAccuracy Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# Step 9: Plot Historical Close Prices and Forecasted Values
df[['Close', 'forecast']].plot(figsize=(12, 8), title="Historical Close Prices and Forecasted Values")
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# ADF Test on Original Series:
# ADF Test Statistic: -0.8155898029288497
# p-value: 0.8144997341990363
# #Lags Used: 0
# Number of Observations Used: 251
# Series is non-stationary.
#
# ADF Test on First Difference:
# ADF Test Statistic: -14.937953227480625
# p-value: 1.3358137634787129e-27
# #Lags Used: 0
# Number of Observations Used: 250
# Series is stationary.
#
# ADF Test on Seasonal Difference:
# ADF Test Statistic: -2.6012540709076446
# p-value: 0.09273835339729486
# #Lags Used: 13
# Number of Observations Used: 226
# Series is non-stationary.
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               AAPL   No. Observations:                  252
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -609.412
# Date:                            Sat, 16 Nov 2024   AIC                           1228.823
# Time:                                    14:51:31   BIC                           1246.205
# Sample:                                         0   HQIC                          1235.828
#                                             - 252
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0948      1.175     -0.081      0.936      -2.397       2.207
# ma.L1          0.1591      1.158      0.137      0.891      -2.110       2.428
# ar.S.L12       0.0013      0.059      0.022      0.982      -0.115       0.117
# ma.S.L12      -0.9991      5.916     -0.169      0.866     -12.595      10.596
# sigma2         8.2492     48.620      0.170      0.865     -87.045     103.543
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               119.13
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.13   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Accuracy Metrics:
# Mean Absolute Error (MAE): 4.5460
# Mean Squared Error (MSE): 26.9558
# Root Mean Squared Error (RMSE): 5.1919

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name "HariharanV11"
# !git config --global user.email "hariharan2022103015@gmail.com"

# %%
# !git clone https://github.com/HariharanV11/Stock-price-prediction.git
# Out:
# Cloning into 'Stock-price-prediction'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
# !mv untitled2.ipynb Stock-price-prediction/
# Out:
# mv: cannot stat 'untitled2.ipynb': No such file or directory

# %%
# !ls drive/MyDrive
# Out:
#  2017
#  2022103015_Hariharan_V.pdf
# '8Yhx2p4f2w-resume (1).pdf'
#  AARTIIND__EQ__NSE__NSE__MINUTE.csv
#  AXISBANK_minute_data_with_indicators.csv
# 'Colab Notebooks'
# 'Copy of CS6007_Module4_Security_Models.pptx'
# 'Copy of CS6007_Module5_Physical_Security_Design.pptx'
# 'Copy of CS6007_Module7_Authentication'
# 'Copy of CS6007_Module8_Authorization.pptx'
#  GOOG-year.csv
# 'Hariharan-Resume (1).pdf'
#  Hariharan-Resume.pdf
#  HATR-I_Hierarchical_Adaptive_Temporal_Relational_Interaction_for_Stock_Trend_Prediction.pdf
#  IMG-20241001-WA0002.jpg
#  IMG-20251023-WA0001.jpg
#  ml.odp
#  ml.pdf
# 'New Resume -(1) (1).pdf'
# 'New Resume -(1) (2).pdf'
# 'New Resume -(1) (3).pdf'
# 'New Resume -(1).pdf'
#  Photo-1.jpg
# 'Resume-5 (1).pdf'
#  Resume-5.pdf
# 'Resume-6 (10).pdf'
# 'Resume-6 (11).pdf'
# 'Resume-6 (12).pdf'
# 'Resume-6 (13).pdf'
# 'Resume-6 (14).pdf'
# 'Resume-6 (15).pdf'
# 'Resume-6 (16).pdf'
# 'Resume-6 (17).pdf'
# 'Resume-6 (18).pdf'
# 'Resume-6 (19).pdf'
# 'Resume-6 (1).pdf'
# 'Resume-6 (20).pdf'
# 'Resume-6 (21).pdf'
# 'Resume-6 (22).pdf'
# 'Resume-6 (23).pdf'
# 'Resume-6 (24).pdf'
# 'Resume-6 (25).pdf'
# 'Resume-6 (26).pdf'
# 'Resume-6 (27).pdf'
# 'Resume-6 (28).pdf'
# 'Resume-6 (29).pdf'
# 'Resume-6 (2).pdf'
# 'Resume-6 (30).pdf'
# 'Resume-6 (31).pdf'
# 'Resume-6 (3).pdf'
# 'Resume-6 (4).pdf'
# 'Resume-6 (5).pdf'
# 'Resume-6 (6).pdf'
# 'Resume-6 (7).pdf'
# 'Resume-6 (8).pdf'
# 'Resume-6 (9).pdf'
#  Resume-6.pdf
# 'Resume_new_change (1).pdf'
# 'Resume_new_change (2).pdf'
# 'Resume_new_change (3).pdf'
#  Resume_new_change.pdf
# 'Screenshot 2024-09-03 102005 (1).png'
# 'Screenshot 2024-09-03 102005.png'
# 'Screenshot 2024-09-10 093910.png'
# 'Screenshot 2024-09-24 103441.png'
# 'Screenshot 2024-10-15 103442.png'
# 'Screenshot 2024-10-22 103405.png'
# 'Screenshot 2024-10-29 121325.png'
# 'Screenshot 2024-11-05 095833.png'
# 'Screenshot 2024-11-12 113350.png'
# 'Screenshot 2025-09-14 141934.png'
# 'Screenshot (4).png'
# 'TEAM_NO_ 11_.pdf'
